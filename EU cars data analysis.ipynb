# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#pd.set_option('max_rows', None)
#pd.set_option('max_columns', None)

# %%
df = pd.read_csv('data.csv')
# Out:
# c:\users\zhecho mitev\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (2,8,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# Index(['ID', 'Country', 'VFN', 'Mp', 'Mh', 'Man', 'MMS', 'Tan', 'T', 'Va',
#        'Ve', 'Mk', 'Cn', 'Ct', 'Cr', 'r', 'm (kg)', 'Mt', 'Enedc (g/km)',
#        'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'Ft', 'Fm',
#        'ec (cm3)', 'ep (KW)', 'z (Wh/km)', 'IT', 'Ernedc (g/km)',
#        'Erwltp (g/km)', 'De', 'Vf', 'Status', 'year'],
#       dtype='object')

# %%
df[df['Country'] == "CZ"]
# Out:
#                 ID Country                       VFN            Mp  \
# 19348      2710009      CZ                       NaN  TOYOTA-MAZDA
# 19354      2710049      CZ                       NaN       RENAULT
# 19363      2710091      CZ                       NaN  TOYOTA-MAZDA
# 19382      2710198      CZ                       NaN   VW GROUP PC
# 19398      2710255      CZ                       NaN   VW GROUP PC
# ...            ...     ...                       ...           ...
# 15365077  13822578      CZ  IP-87A1JRPJR5A_000-VF1-1       RENAULT
# 15365078  13822581      CZ  IP-87A1JRPJR5A_000-VF1-1       RENAULT
# 15365079  13822591      CZ      IP-03_263_0209-ZFA-1     FCA-TESLA
# 15365080  13822594      CZ      IP-03_263_0209-ZFA-1     FCA-TESLA
# 15365081  13822598      CZ  IP-87A1JRPJR5A_000-VF1-1       RENAULT
#
#                   Mh                      Man                      MMS  \
# 19348          MAZDA  MAZDA MOTOR CORPORATION  MAZDA MOTOR CORPORATION
# ...

# %% [markdown]
# * z (Wh/km) - Energy consumption for a kilometer
# * ep (KW) - Electric motor power
# * Enedc (g/km) - New European Driving Cycle (NEDC)
# * Cn - Model name

# %%
average_values = df.groupby('Country').mean()

# %%
average_values
# Out:
#                    ID       r       m (kg)           Mt  Enedc (g/km)  \
# Country
# AT       8.766329e+06  1.0000  1458.357164  1599.795064    125.455194
# BE       4.593011e+06  1.0000  1429.545685  1566.929402    121.531288
# BG       6.793585e+04  1.0000  1461.465087  1584.855116    137.896427
# CY       1.015368e+06  1.0000  1432.900991          NaN    126.885641
# CZ       1.366243e+07  1.0000  1416.935032  1621.177476    128.654805
# DE       5.976396e+06  1.0000  1487.804933  1634.091985    131.344614
# DK       3.975464e+06  1.0000  1353.286607  1476.417034    111.904083
# EE       1.196031e+07  1.0000  1479.867615  1627.944483    130.082635
# ES       1.481769e+07  1.0000  1393.755955  1540.492816    121.327633
# FI       1.101585e+07  1.0000  1457.355041  1568.415138    115.321588
# FR       9.077217e+06  1.0000  1332.005720  1455.425139    113.764009
# GB       8.546332e+06  1.0000  1466.397889  1589.973951    127.692072
# ...

# %%
average_values[['Enedc (g/km)', 'Ewltp (g/km)']].to_csv('average_co2_per_km.csv')

# %%
df.head(20)
# Out:
#         ID Country                  VFN               Mp               Mh  \
# 0   731861      GB                  NaN          HYUNDAI    HYUNDAI ASSAN
# 1   731873      GB  IP-13-WF0-2017-0002  FORD-WERKE GMBH  FORD WERKE GMBH
# 2   731875      GB  IP-13-WF0-2017-0002  FORD-WERKE GMBH  FORD WERKE GMBH
# 3   731877      GB  IP-13-WF0-2017-0002  FORD-WERKE GMBH  FORD WERKE GMBH
# 4   731883      GB                  NaN          HYUNDAI    HYUNDAI ASSAN
# 5   731884      GB                  NaN          HYUNDAI    HYUNDAI ASSAN
# 6   731888      GB                  NaN          HYUNDAI    HYUNDAI ASSAN
# 7   731892      GB  IP-04-YV1-2018-0004              NaN            VOLVO
# 8   731893      GB  IP-04-YV1-2018-0004              NaN            VOLVO
# 9   731906      GB                  NaN     TOYOTA-MAZDA           TOYOTA
# 10  731927      GB                  NaN              KIA              KIA
# 11  731930      GB  IP-13-WF0-2017-0002  FORD-WERKE GMBH  FORD WERKE GMBH
# ...

# %%
df['Ft'].unique()
# Out:
# array(['petrol', 'diesel', 'electric', 'petrol/electric',
#        'diesel/electric', 'lpg', 'ng-biomethane', 'ng', 'hydrogen', 'e85',
#        'unknown'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['GB', 'NO', 'AT', 'IE', 'IS', 'IT', 'NL', 'LV', 'SI', 'CZ', 'SE',
#        'LU', 'CY', 'BE', 'MT', 'BG', 'DE', 'HU', 'PT', 'GR', 'RO', 'DK',
#        'SK', 'LT', 'FR', 'EE', 'PL', 'HR', 'FI', 'ES'], dtype=object)

# %%
df.describe()
# Out:
#                  ID             r        m (kg)            Mt  Enedc (g/km)  \
# count  1.549971e+07  1.549971e+07  1.549957e+07  1.395199e+07  1.544311e+07
# mean   7.749856e+06  1.000004e+00  1.420832e+03  1.555618e+03  1.224571e+02
# std    4.474381e+06  7.658084e-03  2.948810e+02  3.129556e+02  3.234376e+01
# min    1.000000e+00  1.000000e+00  5.200000e+02  5.000000e+02  0.000000e+00
# 25%    3.874928e+06  1.000000e+00  1.198000e+03  1.329000e+03  1.100000e+02
# 50%    7.749856e+06  1.000000e+00  1.390000e+03  1.517000e+03  1.200000e+02
# 75%    1.162478e+07  1.000000e+00  1.581000e+03  1.727000e+03  1.360000e+02
# max    1.549971e+07  2.200000e+01  5.255000e+03  5.669000e+03  5.750000e+02
#
#        Ewltp (g/km)        W (mm)      At1 (mm)      At2 (mm)      ec (cm3)  \
# count  1.432987e+07  1.548333e+07  1.546370e+07  1.542565e+07  1.515368e+07
# mean   1.481538e+02  2.648202e+03  1.543276e+03  1.540937e+03  1.540689e+03
# ...

# %%
df.describe()
# Out:
#                  ID             r        m (kg)            Mt  Enedc (g/km)  \
# count  1.549971e+07  1.549971e+07  1.549957e+07  1.395199e+07  1.544311e+07
# mean   7.749856e+06  1.000004e+00  1.420832e+03  1.555618e+03  1.224571e+02
# std    4.474381e+06  7.658084e-03  2.948810e+02  3.129556e+02  3.234376e+01
# min    1.000000e+00  1.000000e+00  5.200000e+02  5.000000e+02  0.000000e+00
# 25%    3.874928e+06  1.000000e+00  1.198000e+03  1.329000e+03  1.100000e+02
# 50%    7.749856e+06  1.000000e+00  1.390000e+03  1.517000e+03  1.200000e+02
# 75%    1.162478e+07  1.000000e+00  1.581000e+03  1.727000e+03  1.360000e+02
# max    1.549971e+07  2.200000e+01  5.255000e+03  5.669000e+03  5.750000e+02
#
#        Ewltp (g/km)        W (mm)      At1 (mm)      At2 (mm)      ec (cm3)  \
# count  1.432987e+07  1.548333e+07  1.546370e+07  1.542565e+07  1.515368e+07
# mean   1.481538e+02  2.648202e+03  1.543276e+03  1.540937e+03  1.540689e+03
# ...

# %%
df.isna().sum()
# Out:
# ID                      0
# Country                 0
# VFN               7822122
# Mp                 853807
# Mh                      0
# Man                     0
# MMS                406793
# Tan                 20429
# T                   15357
# Va                  21391
# Ve                  21818
# Mk                    974
# Cn                   5202
# Ct                  29419
# Cr                      0
# r                       0
# m (kg)                143
# Mt                1547718
# Enedc (g/km)        56601
# Ewltp (g/km)      1169838
# W (mm)              16376
# At1 (mm)            36015
# At2 (mm)            74060
# Ft                      0
# Fm                    213
# ec (cm3)           346026
# ep (KW)           2326212
# z (Wh/km)        15188984
# IT               13595554
# Ernedc (g/km)    13688552
# Erwltp (g/km)    15491064
# De               14778486
# Vf               12181492
# Status                  0
# year                    0
# dtype: int64

# %%
len(df[df['Ft'] == 'diesel/electric'])
# Out:
# 13245

# %%
df_electric = df[df['Ft'] == 'electric']

# %%
df_electric['Country'].value_counts()
# Out:
# DE    62986
# NO    60245
# NL    59026
# FR    43761
# GB    37727
# SE    15583
# IT    10658
# ES    10264
# AT     9238
# BE     8796
# PT     6884
# DK     5479
# IE     3453
# FI     1888
# HU     1623
# RO     1508
# PL     1444
# LU      964
# IS      914
# CZ      660
# SI      629
# BG      297
# MT      206
# GR      190
# SK      171
# LT      158
# HR      155
# LV       87
# EE       77
# CY        8
# Name: Country, dtype: int64

# %%
df_electric[df_electric['Cn'] == 'MODEL 3'].head(200)
# Out:
#             ID Country                  VFN         Mp     Mh        Man  \
# 609     715771      AT  IP-09-5YJ-2018-0002  FCA-TESLA  TESLA  TESLA INC
# 610     715773      AT  IP-09-5YJ-2018-0002  FCA-TESLA  TESLA  TESLA INC
# 628     715859      AT  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 629     715862      AT  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 630     715864      AT  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# ...        ...     ...                  ...        ...    ...        ...
# 16526  2874187      NL  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 16538  2874238      NL  IP-09-5YJ-2018-0002  FCA-TESLA  TESLA  TESLA INC
# 16548  2874292      NL  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 16549  2874300      NL  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 16550  2874301      NL  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
#
#                     MMS                 Tan    T   Va  ... ec (cm3) ep (KW)  \
# ...

# %%
df_electric[df_electric['Cn'] == 'zoe']
# Out:
# Empty DataFrame
# Columns: [ID, Country, VFN, Mp, Mh, Man, MMS, Tan, T, Va, Ve, Mk, Cn, Ct, Cr, r, m (kg), Mt, Enedc (g/km), Ewltp (g/km), W (mm), At1 (mm), At2 (mm), Ft, Fm, ec (cm3), ep (KW), z (Wh/km), IT, Ernedc (g/km), Erwltp (g/km), De, Vf, Status, year]
# Index: []
#
# [0 rows x 35 columns]

# %%
df_electric_final = df_electric[['Country','Ve', 'Man', 'Cn', 'z (Wh/km)']]

# %%
df_electric_final["Cn"] = df_electric_final["Cn"].str.lower()
# Out:
# <ipython-input-19-a9d6ee073386>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_electric_final["Cn"] = df_electric_final["Cn"].str.lower()

# %%
df_electric_final["Cn"].value_counts()
# Out:
# model 3                          77280
# zoe                              42713
# golf                             23198
# i3                               17872
# nissan leaf 40kwh                14182
#                                  ...
# e-niro/titan/e-motor/392kwh/a        1
# i-miev                               1
# bora                                 1
# q2 l e-tron                          1
# think city                           1
# Name: Cn, Length: 278, dtype: int64

# %%
df_electric_final[df_electric_final['Cn'] == 'zoe'].mode()
# Out:
#   Country            Ve          Man   Cn  z (Wh/km)
# 0      FR  MFLEA0100000  RENAULT SAS  zoe      192.0

# %%
df_electric_final[df_electric_final['z (Wh/km)'].isna()].head(100)
# Out:
#      Country                           Ve                    Man        Cn  \
# 575       NO                       E11B11  HYUNDAI MOTOR COMPANY      kona
# 654       NO                     A1EA5AA1   OPEL AUTOMOBILE GMBH  ampera-e
# 671       NO                       E11B11  HYUNDAI MOTOR COMPANY      kona
# 694       NO  FA1FA1MD001E0GAON1ML1AVR0NA          VOLKSWAGEN AG      golf
# 695       NO  FA1FA1MD001E0GAON1ML1AVR0NA          VOLKSWAGEN AG      golf
# ...      ...                          ...                    ...       ...
# 2541      NO                         BB1N              TESLA INC   model 3
# 2545      NO                         BB1N              TESLA INC   model 3
# 2546      NO                         BB1N              TESLA INC   model 3
# 2547      NO                         BB1N              TESLA INC   model 3
# 2548      NO                         BB1N              TESLA INC   model 3
#
#       z (Wh/km)
# 575         NaN
# 654         NaN
# ...

# %%
df_electric_final.loc[df.Ve == 'E11B11', 'z (Wh/km)'] = 150 #kona kunai
df_electric_final.loc[df.Ve == '0AW40000', 'z (Wh/km)'] = 150 #i3
df_electric_final.loc[df.Ve == 'FA1FA1MD001E0GAON1ML1AVR0NA', 'z (Wh/km)'] = 145 #golf
# Out:
# c:\users\zhecho mitev\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_electric_final.loc[df.Ve == 'BB1N', 'z (Wh/km)'] = 160
df_electric_final.loc[df.Ve == 'Bb1N', 'z (Wh/km)'] = 160
df_electric_final.loc[df.Ve == 'BB1T1', 'z (Wh/km)'] = 160
df_electric_final.loc[df.Ve == 'Bb1T1', 'z (Wh/km)'] = 160
df_electric_final.loc[df.Ve == 'BB1T', 'z (Wh/km)'] = 160

# %%
df_electric_final.loc[df.Ve == 'Pp2N', 'z (Wh/km)'] = 166
df_electric_final.loc[df.Ve == 'PP2N', 'z (Wh/km)'] = 166

# %%
df_Test = df_electric_final.dropna()
len(df_Test)
# Out:
# 271757

# %%
df_electric_final['Ve'].value_counts()
# Out:
# BB1N                       46772
# 0AW40000                   29167
# A02                        27145
# E11B11                     21489
# MFLEA0100000               17242
#                            ...
# FA1FA1MD001E0GA0N1ML2VR        1
# 2                              1
# FA1FAMD001E0A0N1ML02VR0        1
# B19                            1
# FL2                            1
# Name: Ve, Length: 239, dtype: int64

# %%
sns.set()
df_electric['Country'].value_counts().plot(kind='bar', figsize= (10,10))
# Out:
# <AxesSubplot:>

# %%
df_electric.isna().sum()
# Out:
# ID                    0
# Country               0
# VFN              223872
# Mp                38495
# Mh                    0
# Man                   0
# MMS                1415
# Tan                2504
# T                  3628
# Va                 2503
# Ve                 2502
# Mk                   56
# Cn                 2824
# Ct                 2532
# Cr                    0
# r                     0
# m (kg)                8
# Mt               116876
# Enedc (g/km)          0
# Ewltp (g/km)      97905
# W (mm)             2222
# At1 (mm)           2535
# At2 (mm)           5513
# Ft                    0
# Fm                    0
# ec (cm3)         345079
# ep (KW)           57776
# z (Wh/km)        140655
# IT               345079
# Ernedc (g/km)    344989
# Erwltp (g/km)    344982
# De               345069
# Vf               315978
# Status                0
# year                  0
# dtype: int64

# %%
df_electric.head()
# Out:
#          ID Country  VFN                             Mp  \
# 35   732013      GB  NaN  TATA MOTORS JAGUAR LAND ROVER
# 36   732019      GB  NaN  TATA MOTORS JAGUAR LAND ROVER
# 211  732795      GB  NaN                        RENAULT
# 386  733845      GB  NaN                        RENAULT
# 572  715562      NO  NaN                        HYUNDAI
#
#                             Mh                        Man      MMS  \
# 35   JAGUAR LAND ROVER LIMITED  JAGUAR LAND ROVER LIMITED   JAGUAR
# 36   JAGUAR LAND ROVER LIMITED  JAGUAR LAND ROVER LIMITED   JAGUAR
# 211                    RENAULT                RENAULT SAS  RENAULT
# 386                    RENAULT                RENAULT SAS  RENAULT
# 572                    HYUNDAI      HYUNDAI MOTOR COMPANY  HYUNDAI
#
#                      Tan   T      Va  ... ec (cm3) ep (KW) z (Wh/km)   IT  \
# 35   e11*2007/46*4311*03  DH       A  ...      NaN     NaN     246.0  NaN
# ...

# %%
df_electric['z (Wh/km)'].value_counts().head(10)
# Out:
# 160.0    21424
# 206.0    16435
# 166.0    11876
# 154.0     8283
# 172.0     7912
# 149.0     6969
# 115.0     6560
# 159.0     5535
# 192.0     5310
# 131.0     5309
# Name: z (Wh/km), dtype: int64

# %%
plt.hist(df_electric['z (Wh/km)'], bins = 20, range = (100, 300))
# Out:
# (array([2.0000e+00, 7.3240e+03, 4.9890e+03, 9.1630e+03, 1.6478e+04,
#         2.5568e+04, 5.3752e+04, 1.7014e+04, 9.8990e+03, 1.2510e+04,
#         2.0165e+04, 3.1800e+02, 4.2940e+03, 4.0030e+03, 8.6400e+03,
#         4.7250e+03, 6.0700e+02, 1.3000e+02, 1.7300e+03, 3.0000e+00]),
#  array([100., 110., 120., 130., 140., 150., 160., 170., 180., 190., 200.,
#         210., 220., 230., 240., 250., 260., 270., 280., 290., 300.]),
#  <BarContainer object of 20 artists>)

# %%
df_electric['z (Wh/km)'].describe()
# Out:
# count    204424.000000
# mean        174.615153
# std          40.135357
# min          11.000000
# 25%         155.000000
# 50%         165.000000
# 75%         193.000000
# max         413.000000
# Name: z (Wh/km), dtype: float64

# %%
df_electric[df_electric['z (Wh/km)'] == 160]
# Out:
#                 ID Country                  VFN         Mp     Mh        Man  \
# 628         715859      AT  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 629         715862      AT  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 630         715864      AT  IP-09-5YJ-2018-0001  FCA-TESLA  TESLA  TESLA INC
# 1622        754410      GB                  NaN  FCA-TESLA  TESLA  TESLA INC
# 1728        754888      GB                  NaN  FCA-TESLA  TESLA  TESLA INC
# ...            ...     ...                  ...        ...    ...        ...
# 15442621  14973683      ES                  NaN  FCA-TESLA  TESLA  TESLA INC
# 15442622  14973685      ES                  NaN  FCA-TESLA  TESLA  TESLA INC
# 15442625  14973702      ES                  NaN  FCA-TESLA  TESLA  TESLA INC
# 15442626  14973703      ES                  NaN  FCA-TESLA  TESLA  TESLA INC
# 15442627  14973709      ES                  NaN  FCA-TESLA  TESLA  TESLA INC
#
# ...

# %%
electric_vechicles_list = df_electric[~df_electric['z (Wh/km)'].isna()]['Cn'].unique()
len(electric_vechicles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-fad536403a86> in <module>
#       1 electric_vechicles_list = df_electric[~df_electric['z (Wh/km)'].isna()]['Cn'].unique()
# ----> 2 len(electric_vechicles)
#
# NameError: name 'electric_vechicles' is not defined
